# %%
d = {'Indie': 1,
 'Action': 2,
 'Adventure': 3,
 'Singleplayer': 4,
 'Casual': 5,
 'Strategy': 6,
 'Simulation': 7,
 'RPG': 8,
 'Multiplayer': 9,
 'Great Soundtrack': 10,
 'Atmospheric': 11,
 '2D': 12,
 'Puzzle': 13,
 'Early Access': 14,
 'Open World': 15,
 'Story Rich': 16,
 'Co-op': 17,
 'Difficult': 18,
 'Shooter': 19,
 'Sci-fi': 20,
 'First-Person': 21,
 'Horror': 22,
 'VR': 23,
 'Anime': 24,
 'Pixel Graphics': 25,
 'Funny': 26,
 'Fantasy': 27,
 'Platformer': 28,
 'Female Protagonist': 29,
 'Free to Play': 30,
 'FPS': 31,
 'Survival': 32,
 'Gore': 33,
 'Violent': 34,
 'Sandbox': 35,
 'Retro': 36,
 'Arcade': 37,
 'Comedy': 38,
 'Classic': 39,
 'Third Person': 40,
 'Nudity': 41,
 'Massively Multiplayer': 42,
 'Exploration': 43,
 'Point & Click': 44,
 'Visual Novel': 45,
 'Turn-Based': 46,
 'Space': 47,
 'Sports': 48,
 'Rogue-like': 49,
 'Tactical': 50,
 'Cute': 51,
 'Racing': 52,
 'Psychological Horror': 53,
 'Online Co-Op': 54,
 'Zombies': 55,
 'Family Friendly': 56,
 'Sexual Content': 57,
 'Local Co-Op': 58,
 'Local Multiplayer': 59,
 'Controller': 60,
 'Replay Value': 61,
 'Memes': 62,
 'Building': 63,
 'RTS': 64,
 'Fast-Paced': 65,
 'Turn-Based Strategy': 66,
 'Side Scroller': 67,
 'Crafting': 68,
 'Action RPG': 69,
 'Mystery': 70,
 "Shoot 'Em Up": 71,
 'Dark': 72,
 'Survival Horror': 73,
 'Management': 74,
 'Hack and Slash': 75,
 'Physics': 76,
 'War': 77,
 'Historical': 78,
 'Stealth': 79,
 'Rogue-lite': 80,
 'PvP': 81,
 'Realistic': 82,
 'Short': 83,
 'Isometric': 84,
 'Moddable': 85,
 'RPGMaker': 86,
 'Relaxing': 87,
 'Third-Person Shooter': 88,
 'Bullet Hell': 89,
 'Top-Down': 90,
 'Walking Simulator': 91,
 'Dungeon Crawler': 92,
 'Fighting': 93,
 'JRPG': 94,
 'Colorful': 95,
 'Mature': 96,
 'Competitive': 97,
 'Puzzle-Platformer': 98,
 'Procedural Generation': 99,
 'Post-apocalyptic': 100,
 'Medieval': 101,
 'Character Customization': 102,
 'Tower Defense': 103,
 'Military': 104,
 'Choices Matter': 105,
 '4 Player Local': 106,
 'MMORPG': 107,
 'Turn-Based Combat': 108,
 "Beat 'em up": 109,
 'Base-Building': 110,
 'Hidden Object': 111,
 'Cyberpunk': 112,
 'Metroidvania': 113,
 'VR Only': 114,
 'Minimalist': 115,
 'Futuristic': 116,
 'World War II': 117,
 'Dark Fantasy': 118,
 'Team-Based': 119,
 'Perma Death': 120,
 'Robots': 121,
 'Dating Sim': 122,
 'Action-Adventure': 123,
 'Card Game': 124,
 'Economy': 125,
 'Top-Down Shooter': 126,
 'Detective': 127,
 'Turn-Based Tactics': 128,
 'Magic': 129,
 'Education': 130,
 'Aliens': 131,
 'Surreal': 132,
 'Twin Stick Shooter': 133,
 'Driving': 134,
 'Romance': 135,
 'City Builder': 136,
 'Multiple Endings': 137,
 'Parkour': 138,
 'Music': 139,
 'Steampunk': 140,
 'Dark Humor': 141,
 'Kickstarter': 142,
 'Illuminati': 143,
 'Level Editor': 144,
 'Resource Management': 145,
 'Flight': 146,
 'Board Game': 147,
 'Grand Strategy': 148,
 'Choose Your Own Adventure': 149,
 "1990's": 150,
 'Destruction': 151,
 'Utilities': 152,
 'Remake': 153,
 '4X': 154,
 'Dystopian': 155,
 '3D Platformer': 156,
 'Real-Time with Pause': 157,
 '2.5D': 158,
 '2D Fighter': 159,
 'Loot': 160,
 'Real-Time': 161,
 'Cartoony': 162,
 'Match 3': 163,
 'Arena Shooter': 164,
 'Hand-drawn': 165,
 'Abstract': 166,
 'Crime': 167,
 'Stylized': 168,
 'Text-Based': 169,
 'Design & Illustration': 170,
 'CRPG': 171,
 'Mechs': 172,
 'Lovecraftian': 173,
 'Cult Classic': 174,
 'Episodic': 175,
 'Touch-Friendly': 176,
 'Blood': 177,
 'Experimental': 178,
 'Pirates': 179,
 'Voxel': 180,
 'Real Time Tactics': 181,
 'Tactical RPG': 182,
 'MOBA': 183,
 'Psychological': 184,
 '3D Vision': 185,
 'Clicker': 186,
 'e-sports': 187,
 'Interactive Fiction': 188,
 'Tanks': 189,
 'Naval': 190,
 'Split Screen': 191,
 'Space Sim': 192,
 'Animation & Modeling': 193,
 'Ninja': 194,
 'Hex Grid': 195,
 'Cartoon': 196,
 '1980s': 197,
 'Noir': 198,
 'Wargame': 199,
 'Drama': 200,
 'Linear': 201,
 'Demons': 202,
 'Narration': 203,
 'Comic Book': 204,
 'Strategy RPG': 205,
 'Superhero': 206,
 'Rhythm': 207,
 'PvE': 208,
 'Alternate History': 209,
 'Score Attack': 210,
 'Western': 211,
 'Time Travel': 212,
 'GameMaker': 213,
 'Dragons': 214,
 'Assassin': 215,
 'Political': 216,
 'Dinosaurs': 217,
 'God Game': 218,
 'Trading Card Game': 219,
 'Mouse only': 220,
 'Video Production': 221,
 'Psychedelic': 222,
 'Cold War': 223,
 'Hacking': 224,
 'Party-Based RPG': 225,
 'Gothic': 226,
 'Cinematic': 227,
 'Trains': 228,
 'Swordplay': 229,
 'Parody': 230,
 'Games Workshop': 231,
 'Otome': 232,
 'Politics': 233,
 'Crowdfunded': 234,
 'Audio Production': 235,
 'Character Action Game': 236,
 'Trading': 237,
 'Science': 238,
 'Underwater': 239,
 'Hunting': 240,
 'Football': 241,
 'Lore-Rich': 242,
 'Satire': 243,
 'Vampire': 244,
 'Game Development': 245,
 'FMV': 246,
 'Agriculture': 247,
 'Heist': 248,
 'Class-Based': 249,
 'Quick-Time Events': 250,
 'Mod': 251,
 'Bullet Time': 252,
 'Runner': 253,
 'Supernatural': 254,
 'Warhammer 40K': 255,
 'Mythology': 256,
 'World War I': 257,
 'Dark Comedy': 258,
 'Spectacle fighter': 259,
 'Programming': 260,
 'Grid-Based Movement': 261,
 'Software': 262,
 'America': 263,
 'Silent Protagonist': 264,
 'Thriller': 265,
 'Time Attack': 266,
 'Villain Protagonist': 267,
 'Software Training': 268,
 'Soccer': 269,
 'Soundtrack': 270,
 'Fishing': 271,
 'Capitalism': 272,
 'Time Manipulation': 273,
 'TrackIR': 274,
 'Pinball': 275,
 'Rome': 276,
 'Experience': 277,
 'Star Wars': 278,
 'Based On A Novel': 279,
 'Co-op Campaign': 280,
 'Inventory Management': 281,
 'Diplomacy': 282,
 'Mars': 283,
 'Nonlinear': 284,
 'Typing': 285,
 'Chess': 286,
 '6DOF': 287,
 'NSFW': 288,
 'Philisophical': 289,
 'Web Publishing': 290,
 'Gun Customization': 291,
 'Mining': 292,
 'Sniper': 293,
 'Sailing': 294,
 'Asynchronous Multiplayer': 295,
 'Modern': 296,
 'Offroad': 297,
 'Lara Croft': 298,
 'Batman': 299,
 'Horses': 300,
 'Logic': 301,
 'Music-Based Procedural Generation': 302,
 'Mini Golf': 303,
 'LEGO': 304,
 'Conspiracy': 305,
 'Martial Arts': 306,
 'Golf': 307,
 'On-Rails Shooter': 308,
 'Sokoban': 309,
 'Benchmark': 310,
 'Artificial Intelligence': 311,
 'Photo Editing': 312,
 'Transhumanism': 313,
 'Dynamic Narration': 314,
 'Werewolves': 315,
 'Mystery Dungeon': 316,
 'Basketball': 317,
 'Bowling': 318,
 'Gambling': 319,
 'Lemmings': 320,
 'Word Game': 321,
 'Wrestling': 322,
 'Movie': 323,
 'Documentary': 324,
 'Voice Control': 325,
 'Gaming': 326,
 'Conversation': 327,
 'Pool': 328,
 'Faith': 329,
 'Investigation': 330,
 'Tutorial': 331,
 'Bikes': 332,
 'Steam Machine': 333,
 '360 Video': 334,
 'Intentionally Awkward Controls': 335,
 'Cycling': 336,
 'Underground': 337,
 'Spelling': 338,
 'Hardware': 339}

# %%
import re
tmp = []
operand_string = " = db.Column(db.Integer, nullable=False)"
for k in d:
    t = re.sub("[- '&]", "_", k.lower())
    tmp.append("    tag_"+t+operand_string)
tags = "\n".join(tmp)

# %%
tmp = []
for i in range(1, 340):
    tmp.append(f"    tag_{str(i)} = db.Column(db.Boolean, nullable=False)")
tags = "\n".join(tmp)

# %%
result_string = f"""
class GameGenreVector(db.Model):
    appid = db.Column(db.Integer, primary_key=True)
{tags}
"""
print(result_string)
# Out:
# class GameGenreVector(db.Model):
#     appid = db.Column(db.Integer, primary_key=True)
#     tag_1 = db.Column(db.Boolean, nullable=False)
#     tag_2 = db.Column(db.Boolean, nullable=False)
#     tag_3 = db.Column(db.Boolean, nullable=False)
#     tag_4 = db.Column(db.Boolean, nullable=False)
#     tag_5 = db.Column(db.Boolean, nullable=False)
#     tag_6 = db.Column(db.Boolean, nullable=False)
#     tag_7 = db.Column(db.Boolean, nullable=False)
#     tag_8 = db.Column(db.Boolean, nullable=False)
#     tag_9 = db.Column(db.Boolean, nullable=False)
#     tag_10 = db.Column(db.Boolean, nullable=False)
#     tag_11 = db.Column(db.Boolean, nullable=False)
#     tag_12 = db.Column(db.Boolean, nullable=False)
#     tag_13 = db.Column(db.Boolean, nullable=False)
#     tag_14 = db.Column(db.Boolean, nullable=False)
#     tag_15 = db.Column(db.Boolean, nullable=False)
#     tag_16 = db.Column(db.Boolean, nullable=False)
#     tag_17 = db.Column(db.Boolean, nullable=False)
# ...
